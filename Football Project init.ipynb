# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
df = pd.read_csv('PBP - 2018 - Week 1.csv')

# %%
df.head()
# Out:
#       gameId  year  week  homeId homeTeam homeAbbr  awayId  awayTeam awayAbbr  \
# 0  401013357  2018     1     113    UMass    UMASS    2184  Duquesne      DUQ
# 1  401013357  2018     1     113    UMass    UMASS    2184  Duquesne      DUQ
# 2  401013357  2018     1     113    UMass    UMASS    2184  Duquesne      DUQ
# 3  401013357  2018     1     113    UMass    UMASS    2184  Duquesne      DUQ
# 4  401013357  2018     1     113    UMass    UMASS    2184  Duquesne      DUQ
#
#    driveIndex  playIndex  offenseId offenseTeam offenseAbbr  defenseId  \
# 0           0          0        113       UMass       UMASS       2184
# 1           0          1       2184    Duquesne         DUQ        113
# 2           0          2       2184    Duquesne         DUQ        113
# 3           0          3       2184    Duquesne         DUQ        113
# 4           1          0        113       UMass       UMASS       2184
#
# ...

# %%
df.columns
# Out:
# Index(['gameId', 'year', 'week', 'homeId', 'homeTeam', 'homeAbbr', 'awayId',
#        'awayTeam', 'awayAbbr', 'driveIndex', 'playIndex', 'offenseId',
#        'offenseTeam', 'offenseAbbr', 'defenseId', 'defenseTeam', 'defenseAbbr',
#        'homeScore', 'awayScore', 'isScoringPlay', 'quarter', 'clock', 'type',
#        'down', 'distance', 'yardLine', 'yardsGained', 'endYardLine',
#        'description'],
#       dtype='object')

# %%
df[df.type == "Pass Interception Return"]
# Out:
#           gameId  year  week  homeId        homeTeam homeAbbr  awayId  \
# 3      401013357  2018     1     113           UMass    UMASS    2184
# 71     401013357  2018     1     113           UMass    UMASS    2184
# 401    401022510  2018     1      36  Colorado State      CSU      62
# 1030   401019470  2018     1      41           UConn    UCONN    2116
# 1169   401021651  2018     1    2247   Georgia State     GAST     338
# ...          ...   ...   ...     ...             ...      ...     ...
# 15851  401079833  2018     1     151             ECU      ECU    2448
# 15980  401013095  2018     1      99             LSU      LSU    2390
# 16126  401013096  2018     1      52             FSU      FSU     259
# 16203  401013096  2018     1      52             FSU      FSU     259
# 16211  401013096  2018     1      52             FSU      FSU     259
#
#           awayTeam awayAbbr  driveIndex  playIndex  offenseId     offenseTeam  \
# ...

# %%
df[df.gameId == 401013357]
# Out:
#         gameId  year  week  homeId homeTeam homeAbbr  awayId  awayTeam  \
# 0    401013357  2018     1     113    UMass    UMASS    2184  Duquesne
# 1    401013357  2018     1     113    UMass    UMASS    2184  Duquesne
# 2    401013357  2018     1     113    UMass    UMASS    2184  Duquesne
# 3    401013357  2018     1     113    UMass    UMASS    2184  Duquesne
# 4    401013357  2018     1     113    UMass    UMASS    2184  Duquesne
# ..         ...   ...   ...     ...      ...      ...     ...       ...
# 172  401013357  2018     1     113    UMass    UMASS    2184  Duquesne
# 173  401013357  2018     1     113    UMass    UMASS    2184  Duquesne
# 174  401013357  2018     1     113    UMass    UMASS    2184  Duquesne
# 175  401013357  2018     1     113    UMass    UMASS    2184  Duquesne
# 176  401013357  2018     1     113    UMass    UMASS    2184  Duquesne
#
#     awayAbbr  driveIndex  playIndex  offenseId offenseTeam offenseAbbr  \
# ...

# %%
umass_duq = df[df.gameId == 401013357]

# %%
umass_duq.drop(columns=['homeTeam', 'awayTeam', 'gameId', 'homeId', 'offenseId', 'awayId', 'defenseId', 'offenseTeam', 'defenseTeam'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-aef3bbbd60be> in <module>
# ----> 1 umass_duq.drop(columns=['homeTeam', 'awayTeam', 'gameId', 'homeId', 'offenseId', 'awayId', 'defenseId', 'offenseTeam', 'defenseTeam'])
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...

# %%
display(umass_duq)
# Out:
#      year  week homeAbbr awayAbbr  driveIndex  playIndex offenseAbbr  \
# 0    2018     1    UMASS      DUQ           0          0       UMASS
# 1    2018     1    UMASS      DUQ           0          1         DUQ
# 2    2018     1    UMASS      DUQ           0          2         DUQ
# 3    2018     1    UMASS      DUQ           0          3         DUQ
# 4    2018     1    UMASS      DUQ           1          0       UMASS
# 5    2018     1    UMASS      DUQ           2          0       UMASS
# 6    2018     1    UMASS      DUQ           2          1         DUQ
# 7    2018     1    UMASS      DUQ           2          2         DUQ
# 8    2018     1    UMASS      DUQ           2          3         DUQ
# 9    2018     1    UMASS      DUQ           2          4         DUQ
# 10   2018     1    UMASS      DUQ           2          5         DUQ
# 11   2018     1    UMASS      DUQ           3          0       UMASS
# 12   2018     1    UMASS      DUQ           3          1       UMASS
# ...

# %%
umass_duq.query('offenseAbbr == "DUQ" & isScoringPlay == True')
# Out:
#      year  week homeAbbr awayAbbr  driveIndex  playIndex offenseAbbr  \
# 45   2018     1    UMASS      DUQ           8          6         DUQ
# 96   2018     1    UMASS      DUQ          16         11         DUQ
# 111  2018     1    UMASS      DUQ          19          5         DUQ
# 147  2018     1    UMASS      DUQ          22         19         DUQ
#
#     defenseAbbr  homeScore  awayScore  isScoringPlay  quarter  clock  \
# 45        UMASS         21          3           True        1   0:50
# 96        UMASS         35          9           True        2   0:05
# 111       UMASS         49          9           True        3  10:09
# 147       UMASS         56         15           True        4  10:27
#
#                               type  down  distance  yardLine  yardsGained  \
# 45                 Field Goal Good     4         3        14           32
# 96               Passing Touchdown     3         0         5            5
# ...

# %%
len(umass_duq.query('offenseAbbr == "UMASS" & isScoringPlay == True'))
# Out:
# 8

# %%
print(str(len(df.query('type == "Passing Touchdown"'))) + " Passing Touchdowns")
print(str(len(df.query('type == "Rushing Touchdown"'))) + " Rushing Touchdowns")
# Out:
# 332 Passing Touchdowns
# 300 Rushing Touchdowns

# %%
week_2 = pd.read_csv('PBP - 2018 - Week 2.csv')

# %%
len(week_2.gameId.unique())
# Out:
# 11

# %%
print(str(len(week_2.query('type == "Passing Touchdown"'))) + " Passing Touchdowns")
print(str(len(week_2.query('type == "Rushing Touchdown"'))) + " Rushing Touchdowns")
# Out:
# 35 Passing Touchdowns
# 28 Rushing Touchdowns

# %%
week_2[week_2['gameId'] == 401014988]
# Out:
#          gameId  year  week  homeId homeTeam homeAbbr  awayId awayTeam  \
# 1797  401014988  2018     2      62  Hawai'i      HAW     242     Rice
# 1798  401014988  2018     2      62  Hawai'i      HAW     242     Rice
# 1799  401014988  2018     2      62  Hawai'i      HAW     242     Rice
# 1800  401014988  2018     2      62  Hawai'i      HAW     242     Rice
# 1801  401014988  2018     2      62  Hawai'i      HAW     242     Rice
# 1802  401014988  2018     2      62  Hawai'i      HAW     242     Rice
# 1803  401014988  2018     2      62  Hawai'i      HAW     242     Rice
# 1804  401014988  2018     2      62  Hawai'i      HAW     242     Rice
# 1805  401014988  2018     2      62  Hawai'i      HAW     242     Rice
# 1806  401014988  2018     2      62  Hawai'i      HAW     242     Rice
# 1807  401014988  2018     2      62  Hawai'i      HAW     242     Rice
# 1808  401014988  2018     2      62  Hawai'i      HAW     242     Rice
# ...

# %%
week_2.query('type == "Passing Touchdown"')
# Out:
#          gameId  year  week  homeId       homeTeam homeAbbr  awayId  \
# 7     401013099  2018     2      52            FSU      FSU    2535
# 40    401013099  2018     2      52            FSU      FSU    2535
# 80    401013099  2018     2      52            FSU      FSU    2535
# 102   401013099  2018     2      52            FSU      FSU    2535
# 196   401013099  2018     2      52            FSU      FSU    2535
# 217   401014982  2018     2     295   Old Dominion      ODU    2229
# 256   401014982  2018     2     295   Old Dominion      ODU    2229
# 277   401014982  2018     2     295   Old Dominion      ODU    2229
# 307   401014982  2018     2     295   Old Dominion      ODU    2229
# 342   401014982  2018     2     295   Old Dominion      ODU    2229
# 403   401014991  2018     2    2439           UNLV     UNLV    2638
# 492   401014991  2018     2    2439           UNLV     UNLV    2638
# 548   401014991  2018     2    2439           UNLV     UNLV    2638
# ...
